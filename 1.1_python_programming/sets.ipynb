# %% [markdown]
# <h1>Sets</h1>

# %%
#creating a set
numbers = {1,2,3,4}
colors = {"red", "green", "blue"}
empty = set()

# %%
#adding elements use .add("item")
fruits = {"apple", "banana"}
fruits.add("cherry")
print(fruits)
# Out:
# {'banana', 'cherry', 'apple'}

# %%
#update: adding 2 or 
fruits.update(["pear","mango"])
fruits
# Out:
# {'apple', 'banana', 'cherry', 'mango', 'pear'}

# %%
#remove and discard: remove raises an error if elt is absent but discard doesn't
#fruits.remove("banana")
fruits.discard(2)
fruits
# Out:
# {'cherry'}

# %%
#pop randomly removes 
fruits
# Out:
# {'cherry'}

# %%
A = {}
B = {}
print(a|b)
print(a&b)

# %%
#diference method
a = {1,2,3}
b = {3,4,5}
print(a-b)
# Out:
# {1, 2}

# %%
#symmetric difference
print(a^b)
# Out:
# {1, 2, 4, 5}

# %%
#looping through a set undefined order
for i in {1,4,56}:
    print(i)
# Out:
# 56
# 1
# 4

# %%
#set comprehension
squares = []
for number in range(1,11):
    squar = number*number
    squares.append(squar)
print(squares)

#using list comprehension
sqn = [i*i for i in range(1,11)]
sqn
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81, 100]
# [1, 4, 9, 16, 25, 36, 49, 64, 81, 100]
