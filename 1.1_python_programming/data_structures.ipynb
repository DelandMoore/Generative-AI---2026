# %% [markdown]
# <h1>Data Structures</h1>

# %%
# List
#use "type" to verify datatypes and structures
#list identifier is a "[]"
names = ["sunday","tuesday","wednesday"]


print(type(names))
# Out:
# <class 'list'>

# %% [markdown]
# <h1>Accessing Items</h1>

# %%
names[0]
# Out:
# 'ngwa'

# %%
#To add
names.append("thursday")
names
# Out:
# ['ngwa', 'chi', 'berinyuy', 'thursday']

# %%
#Exercise
Even_numbers = []
number = int(input("enter a number: "))

if number%2 == 0:
    Even_numbers.append(number)
else:
    Even_numbers.append(4096)
print(Even_numbers)
# Out:
# enter a number:  -5
# ['4096']

# %% [markdown]
# <h1>Sorting</h1>

# %%
odd_numbers = [201,555,1,3,9,13,57, 33333333]
sorted_odd_nums = sorted(odd_numbers)
print(sorted_odd_nums)
# Out:
# [1, 3, 9, 13, 57, 201, 555, 33333333]

# %% [markdown]
# <h1>deleting from the back</h1>

# %%
sorted_odd_nums.pop()
# Out:
# <function list.pop(index=-1, /)>

# %%
sorted_odd_nums.pop()
# Out:
# 555
