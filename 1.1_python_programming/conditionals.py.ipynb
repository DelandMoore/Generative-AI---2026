# %%
# CONDITIONALS: Allow you execute code only if a condition is true
age = int(input("Enter your age: "))
if age > 20:
    print("Age is graeter than 20")
# Out:
# Enter your age:  30
# Age is graeter than 20

# %%
# if ... else condition
height = 23
if height >= 23:
    print("Tall")
    print("Indeed your height is above 33")
else:
    print("You are short")
    
print("Thanks for using our program")
# Out:
# Tall
# Indeed your height is above 33
# Thanks for using our program

# %%
#School grading system using if...elif.....else
score = int(input("Enter your score: "))
if score > 90:
    print("Student scored an A+ grade")
elif score >= 80 and score <=90:
    print("Student scored an A grade")
elif score >=70 and score <=79:
    print("Student scored a B+ grade")
elif score >= 60 and score <=69:
    print("Student scored a B grade")
elif score > 50 and score <=59:
    print("Student scored a C grade")

else:
    print("Student failed")
# Out:
# Enter your score:  60
# Student scored a B grade
