# %%
# string methods you need to know as an AI engineer
print("Hello")
# Out:
# Hello

# %% [markdown]
# ## Exploring python list methods
# - .capitalise, .upper, .lower, .slice, indexing and accessing string elements, .strip, .title, .endswith

# %%
text = "Generative Ai is my best field "
print(text.capitalize())
print(text.lower())
print(text.upper())
print(text.title())
print(text.strip())
# Out:
# Generative ai is my best field
# generative ai is my best field
# GENERATIVE AI IS MY BEST FIELD
# Generative Ai Is My Best Field
# Generative Ai is my best field

# %%
remove_text = text.strip()
print(len(remove_text))
# Out:
# 30

# %%
greetings = "Hello, seed"
#indexing in programming
greetings[0]
# Out:
# 'H'

# %%
# slicing
greeting2 = "my goat is haaland"
gsd=len(greeting2)
#greeting2[0:7]
#greeting2[10:]
#reeting2[3:7]


#get me the first 7 elements
# Out:
#   Cell In[24], line 7
#     for i in range(0:gsd):
#                     ^
# SyntaxError: invalid syntax

# %%
# AI prompt Analyzer
prompt = input("Please enter a prompt of your choice: ")
number_of_xters = len(prompt)
uppercase = prompt.upper()
number_of_words= len(prompt.split())
print(f"Original prompt: {prompt} ")
print(f"Number of words: There are {number_of_words} words")
print(f"Number of characters: {number_of_xters}")
print(f"Prompt in uppercase: {uppercase}")
if number_of_xters >= 15:
    print(f"Prompt is long with {number_of_xters} characters")
else:
    print("Prompt is short")
# Out:
# Please enter a prompt of your choice:  I am the boy from Batibo
# Original prompt: I am the boy from Batibo /n
# Number of words: There are 6 words/n
# Number of characters: 24/n
# Prompt in uppercase: I AM THE BOY FROM BATIBO/n
# Prompt is long with 24 characters
